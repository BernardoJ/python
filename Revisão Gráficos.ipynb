# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # Histograma

# %%
tb["cm"].plot.hist(bins = 20)
plt.show()

# %% [markdown]
# # Densidade

# %%
plt.close()
tb["cm"].plot.density(color = "red")
plt.show()

# %%
plt.close()
tb2 = tb[tb.country.isin(["Italy", "England"])]
tb2.groupby(["country"])["cm"].plot.density()
plt.legend(); plt.show() #Adiciona a legenda

# %% [markdown]
# # Histograma e Densidade

# %%
plt.close()
sns.distplot(tb.loc[tb.cm.notnull(), ["cm"]],
             hist = True, kde = True, rug = True)
plt.show()
# Out:
# C:\Users\berna\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\berna\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Gráfico de Barras

# %%
plt.close()
sns.barplot(tb2.country, tb2.yel)
plt.show()
# Out:
# C:\Users\berna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Dispersão

# %%
plt.close()
sns.scatterplot(tb2.cm, tb2.kg, hue = tb2.country)
plt.show()
# Out:
# C:\Users\berna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Boxplot

# %%
plt.close()
sns.boxplot(tb2.country, tb2.cm)
plt.show()
# Out:
# C:\Users\berna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Gráfico de Violino

# %%
plt.close()
sns.violinplot(tb2.country, tb2.kg)
plt.show()
# Out:
# C:\Users\berna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Matriz de diagramas de dispersão

# %%
plt.close()
sns.pairplot(data = tb2, vars = ["cm", "kg", "age"], hue = "country")
plt.show()
